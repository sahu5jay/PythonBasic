# %% [markdown]
# Que-1 Explain the key features of Python that make it a popular choice for programming
#   Ans-1 Python is a prferable language for programing for data Analytics for its following features like-
#   1. Simple and eassy to understand.
#   2. Waste liberary used for the data Analytics.
#   3. Platform independent can be used in Mac or Windows.
#   4. Dynamically typed language - code is runned line by line.
#
# Que-2 Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#   Ans-2 Python language have many predefined keywords which are part of the Python language syntax and cannot be used as variable names, function names, or identifiers.
#   for ex-
#   1. if,else - this are in conditional statements.
#   2. for, while - used in loop iteration.
#   3. continue, break - for controling the itteration of the loop.
#   4. and,or,not - operators for checking the conditions.
#
# Que-3 Compare and contrast mutable and immutable objects in Python with examples.
#   Ans-3 Mutuable are the objects in the python language which can be changed after creation of the objects.
#   for ex-list,disc, set are the data struture whch can be changed.
#
#   Immutable are the object in the language which cannot be changed after creation.
#   if we try to change the object a new object will be created insteed of making change in that object.
#   for ex - int, float, string, tuple, bool.
#
# Que-4 Discuss the different types of operators in Python and provide examples of how they are used.
#   Ans-4 Python provide wast types of operator for doing my operation in the program
#   For ex-
#   1.Arthematic operator
#   This operator is used for the calculation of many numerical operation in the program. ex-+,-</,*.
#   2.Assignment Operators
#   Used to assign the value to the variable ex-=,+=,=+,etc.
#   3.Comparison (Relational) Operators
#   Relational operator ae the operator which are used finding the relation between the two different variable. ex- ==,=>,<=,!=,etc.
#
# Que-5 Explain the concept of type casting in Python with examples.
#   Ans-5 Typecasting is the predefined function which is used to convert one datatype to the other datatype.
#   the Typecasting are of two types.
#   1. Implecite typecasting- automatically done by the python
#   ex a = 5   int
#      b = 2.0 float
#      c = a + b result is float
#      print(c)  Output: 7.0
#      print(type(c)).
#   2. Explacite typecasing- done by the programmer ex- int(), float(), str(), bool(), list().
#
# Que-6 How do conditional statements work in Python? Illustrate with examples
#   Ans-6 Contitional statement are the statement which are completeed based on the condition that are provide by the programmer.
#   this condition is archived using the conditional statement if,ifelse,elif etc.
#   for ex-
#   marks = 85
#   if marks >= 90:
#     print("Grade A")
#   elif marks >= 75:
#     print("Grade B")
#   elif marks >= 60:
#     print("Grade C")
#   else:
#     print("Grade D")
#
# Que-7 Describe the different types of loops in Python and their use cases with examples.
#   Ans-7 Python uses two different types of loop for the iteration of the loop based on the condition provided in the question.
#   1.while loop
#     Used when we don’t know beforehand how many times to iterate.
#     Runs the iteration till the condition is true.
#     i = 1
#       while i <= 5:
#       print(i)
#       i += 1
#   2. For loop
#     Used when you know in advance how many times you want to iterate.
#     fruits = ["apple", "banana", "cherry"]
#     for fruit in fruits:
#     print(fruit)
